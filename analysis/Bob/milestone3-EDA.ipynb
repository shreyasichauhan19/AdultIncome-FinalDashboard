# %% [markdown]
# ### Import pandas as a software library
# ---Read the csv file by pandas
# [pandas tutorial](https://pandas.pydata.org/)
#
# Research question: How does education affect the annual salary?

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
my_data = pd.read_csv("adult.csv") 
my_data
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
my_data.dropna()
my_data
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# Basically, the data set did not have any NA values. After drop missing values, the rows keep the same as before.

# %%
df1 = (
    pd.read_csv('adult.csv', usecols=['education-num','annualsalary'])
    .sort_values("education-num", ascending=True)
)
df1
# Out:
#        education-num annualsalary
# 22940              1        <=50K
# 13248              1        <=50K
# 21370              1        <=50K
# 25943              1        <=50K
# 21388              1        <=50K
# ...              ...          ...
# 10647             16         >50K
# 12074             16        <=50K
# 28758             16        <=50K
# 4597              16         >50K
# 15708             16         >50K
#
# [32561 rows x 2 columns]

# %%
df1['education-num'].plot(kind='hist')

# %% [markdown]
# This chart shows the total person of this data set and the education year they have done.

# %%
data = pd.read_excel("df1.xlsx")
data.plot()

# %% [markdown]
# For this chart, It investigates the relationship between education year and the number of person who have annunal income below or over 50K. By the way, it is hard to use scatter plot to investigate the relationship between income and education year. For this dataset, the income was counted by 50K per year. The data set only show the person has over 50K or less than 50K. Therefore, the income can not be a variable but measure as a number to show how many person are over or below 50K dollars per year.

# %% [markdown]
# Also, for the education year, The more educated person has higher rate of anuanal income above 50K.After calculation, the average education year of person who have over 50K income is 11.29 years. The average education year of person who have below 50K income is 9.70 years.
